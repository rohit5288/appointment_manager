# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df=pd.read_csv('gender_inequality.csv')

# %%
df
# Out:
#      GII Rank                          Country Gender Inequality Index (GII)  \
# 0         1.0                           Norway                         0.067
# 1         2.0                        Australia                          0.11
# 2         3.0                      Switzerland                         0.028
# 3         4.0                          Denmark                         0.048
# 4         5.0                      Netherlands                         0.062
# ..        ...                              ...                           ...
# 190       NaN          Europe and Central Asia                           0.3
# 191       NaN  Latin America and the Caribbean                         0.415
# 192       NaN                       South Asia                         0.536
# 193       NaN               Sub-Saharan Africa                         0.575
# 194       NaN                            World                         0.449
#
# ...

# %%
df.shape
# Out:
# (195, 10)

# %%
df.shape
# Out:
# (195, 10)

# %%
gii=df['Gender Inequality Index (GII)']
mmr=df['Maternal Mortality Ratio']
abr=df['Adolescent Birth Rate']
prp=df['Percent Representation in Parliament']
psef=df['Population with Secondary Education (Female)']
psem=df['Population with Secondary Education (Male)']
lfpf=df['Labour Force Participation Rate (Female)']
lfpm=df['Labour Force Participation Rate (Male)']

# %%
plt.scatter(gii,mmr)
plt.title('Scatter plot b/w GII and Maternal Mortality Ratio')
plt.show()

# %%
plt.scatter(gii,abr)
plt.title('Scatter plot b/w GII and Adolescent Birth Rate')
plt.show()

# %%
plt.scatter(gii,prp)
plt.title('Scatter plot b/w GII and Representation in Parliament')
plt.show()

# %%
plt.scatter(gii,psef)
plt.title('Scatter plot b/w GII and Population with Secondary Education (Female)')
plt.show()

# %%
plt.scatter(gii,psem)
plt.title('Scatter plot b/w GII and Population with Secondary Education (Male)')
plt.show()

# %%
plt.scatter(gii,lfpf)
plt.title('Scatter plot b/w GII and Labour Force Participation Rate (Female)')
plt.show()

# %%
plt.scatter(gii,lfpm)
plt.title('Scatter plot b/w GII and Labour Force Participation Rate (Male)')
plt.show()
